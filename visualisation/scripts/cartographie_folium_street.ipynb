# %% [markdown]
# # Cartographie et diagramme des items exposés selon l'adresse des exposants

# %% [markdown]
# ## Cartographie

# %%
#Localiser le répertoire de travail 

import os
os.getcwd()
# Out:
# '/Users/frederinepradier/GitHub/Scripts/scripts'

# %%
#Chargement des librairies

import pandas as pd

import matplotlib.pyplot as plt  
from collections import Counter
import matplotlib.ticker as ticker

# !pip install folium
import folium
# Out:
# Requirement already satisfied: folium in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from folium) (3.0.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from folium) (1.21.2)
# Requirement already satisfied: branca>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from folium) (0.4.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from folium) (2.26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->folium) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->folium) (2.0.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages (from requests->folium) (1.26.7)
# WARNING: You are using pip version 22.0.4; however, version 22.2.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
#Désignation du fichier de travail (tableur csv)

path = '../data/PCP_complete.tsv'

# %%
#Création d'un tableur (dataframe)

df = pd.read_csv(path, sep='\t', index_col=[0])

# %%
#Aperçu des données 

df.head(3)
# Out:
#               Exhibition_Date First name Last name Last name of the artist  \
# File
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
#
#              First name of the artist Sex of the artist (F/M/FM/empty)  \
# File
# PCP_1894.tsv                      NaN                             male
# PCP_1894.tsv                      NaN                             male
# PCP_1894.tsv                      NaN                             male
#
#              Membership in movement, if applicable  \
# File
# PCP_1894.tsv                                   NaN
# PCP_1894.tsv                                   NaN
# PCP_1894.tsv                                   NaN
#
#                      Biographical elements  \
# File
# PCP_1894.tsv    268, rue Haute, Bruxelles.
# PCP_1894.tsv    268, rue Haute, Bruxelles.
# PCP_1894.tsv    268, rue Haute, Bruxelles.
#
#              Detailed address of the artist, as it appears in the catalogue  \
# File
# PCP_1894.tsv                         268, rue Haute, Bruxelles.
# PCP_1894.tsv                         268, rue Haute, Bruxelles.
# PCP_1894.tsv                         268, rue Haute, Bruxelles.
#
#              Country of the artist City of the artist  ...  \
# File                                                   ...
# PCP_1894.tsv               Belgium   City of Brussels  ...
# PCP_1894.tsv               Belgium   City of Brussels  ...
# PCP_1894.tsv               Belgium   City of Brussels  ...
#
#              Street number of the artist's address  \
# File
# PCP_1894.tsv                                   268
# PCP_1894.tsv                                   268
# PCP_1894.tsv                                   268
#
#               Street name of the address  Street coordinate location  \
# File
# PCP_1894.tsv      Rue Haute - Hoogstraat          50.837829,4.349341
# PCP_1894.tsv      Rue Haute - Hoogstraat          50.837829,4.349341
# PCP_1894.tsv      Rue Haute - Hoogstraat          50.837829,4.349341
#
#              Street lat Street long Number          Title of artwork  \
# File
# PCP_1894.tsv  50.837829    4.349341      1   La Leçon de d'anatomie.
# PCP_1894.tsv  50.837829    4.349341      2                La Charge.
# PCP_1894.tsv  50.837829    4.349341      3          Brutus et Saïda.
#
#               Subtitle Dimension_bis Medium_bis
# File
# PCP_1894.tsv       NaN           NaN        NaN
# PCP_1894.tsv       NaN           NaN        NaN
# PCP_1894.tsv       NaN           NaN        NaN
#
# [3 rows x 23 columns]

# %%
#Aperçu des données 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5050 entries, PCP_1894.tsv to PCP_1895.tsv
# Data columns (total 23 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Exhibition_Date                                                 5050 non-null   int64
#  1   First name Last name                                            5050 non-null   object
#  2   Last name of the artist                                         5050 non-null   object
#  3   First name of the artist                                        4825 non-null   object
#  4   Sex of the artist (F/M/FM/empty)                                5050 non-null   object
#  5   Membership in movement, if applicable                           2411 non-null   object
#  6   Biographical elements                                           5049 non-null   object
#  7   Detailed address of the artist, as it appears in the catalogue  5048 non-null   object
#  8   Country of the artist                                           5050 non-null   object
#  9   City of the artist                                              5033 non-null   object
#  10  City coordinate location                                        5031 non-null   object
#  11  City lat                                                        5031 non-null   float64
#  12  City long                                                       5031 non-null   float64
#  13  Street number of the artist's address                           4830 non-null   object
#  14  Street name of the address                                      4358 non-null   object
#  15  Street coordinate location                                      2774 non-null   object
#  16  Street lat                                                      2774 non-null   float64
#  17  Street long                                                     2774 non-null   float64
#  18  Number                                                          5050 non-null   object
#  19  Title of artwork                                                5050 non-null   object
#  20  Subtitle                                                        3543 non-null   object
#  21  Dimension_bis                                                   2824 non-null   object
#  22  Medium_bis                                                      3278 non-null   object
# dtypes: float64(4), int64(1), object(18)
# memory usage: 946.9+ KB

# %%
#Créer un nouveau tableur avec le compte du nombre d'items par adresse des exposants

street_nb = Counter(df["Street name of the address"].sort_values(ascending=True).tolist()).most_common()
df_street = pd.DataFrame(street_nb, columns=["Street name of the address", 'Count'])
df_street
# Out:
#     Street name of the address  Count
# 0                          NaN    692
# 1          boulevard Haussmann    148
# 2              rue Paul-Baudry     68
# 3             Rue François-Ier     63
# 4        boulevard Malesherbes     60
# ..                         ...    ...
# 914       rue du Château-d'Eau      1
# 915        rue du Gros-Horloge      1
# 916         ruelle des Banques      1
# 917        via Rione Sirignano      1
# 918         villa von Weinhart      1
#
# [919 rows x 2 columns]

# %%
df_street = df_street.set_index("Street name of the address").join(df.set_index("Street name of the address"), how="right").reset_index() 
df_street.head()
# Out:
#   Street name of the address  Count  Exhibition_Date    First name Last name  \
# 0              3 W  29me rue      2             1902        Alfred STIEGLITZ
# 1              3 W  29me rue      2             1902        Alfred STIEGLITZ
# 2              3 W. 29me rue      6             1902  Mme Gertrude KÄSEBIER
# 3              3 W. 29me rue      6             1902  Mme Gertrude KÄSEBIER
# 4              3 W. 29me rue      6             1902  Mme Gertrude KÄSEBIER
#
#   Last name of the artist First name of the artist  \
# 0               STIEGLITZ                   Alfred
# 1               STIEGLITZ                   Alfred
# 2               KÄSEBIER              Mme Gertrude
# 3               KÄSEBIER              Mme Gertrude
# 4               KÄSEBIER              Mme Gertrude
#
#   Sex of the artist (F/M/FM/empty) Membership in movement, if applicable  \
# 0                             male                           Linked Ring
# 1                             male                           Linked Ring
# 2                           female                           Linked Ring
# 3                           female                           Linked Ring
# 4                           female                           Linked Ring
#
#                          Biographical elements  \
# 0    L. R. 3 W, 29me rue, New-York (U. S. A.).
# 1    L. R. 3 W, 29me rue, New-York (U. S. A.).
# 2    L. R. 3 W. 29me rue, New-York (U. S. A.).
# 3    L. R. 3 W. 29me rue, New-York (U. S. A.).
# 4    L. R. 3 W. 29me rue, New-York (U. S. A.).
#
#   Detailed address of the artist, as it appears in the catalogue  ...  \
# 0                3 W, 29me rue, New-York (U. S. A.).              ...
# 1                3 W, 29me rue, New-York (U. S. A.).              ...
# 2                3 W. 29me rue, New-York (U. S. A.).              ...
# 3                3 W. 29me rue, New-York (U. S. A.).              ...
# 4                3 W. 29me rue, New-York (U. S. A.).              ...
#
#   City long Street number of the artist's address Street coordinate location  \
# 0     -74.0                                                              NaN
# 1     -74.0                                                              NaN
# 2     -74.0                                                              NaN
# 3     -74.0                                                              NaN
# 4     -74.0                                                              NaN
#
#    Street lat  Street long Number                Title of artwork  Subtitle  \
# 0         NaN          NaN    465                      Printemps.       NaN
# 1         NaN          NaN    466       Étude d'éclairage. D. Pl.    D. Pl.
# 2         NaN          NaN    290               Homme au Chapeau.       Pl.
# 3         NaN          NaN    291                       Cathryne.       Gb.
# 4         NaN          NaN    292  Portrait de M. Clarence White.       Gb.
#
#      Dimension_bis                      Medium_bis
# 0              NaN                             NaN
# 1  Épreuve directe               Papier au platine
# 2              NaN               Papier au platine
# 3              NaN  Procédé à la gomme bichromatée
# 4              NaN  Procédé à la gomme bichromatée
#
# [5 rows x 24 columns]

# %%
df_street.drop_duplicates(subset=["Street name of the address"], keep = 'first', inplace=True)
df_street
# Out:
#      Street name of the address  Count  Exhibition_Date  \
# 0                 3 W  29me rue      2             1902
# 2                 3 W. 29me rue      6             1902
# 8                 Arnisson Road     10             1896
# 18            Avenue Saint-Maur      5             1906
# 23                   Beechcroff      1             1906
# ...                         ...    ...              ...
# 4350    via Giuseppe Zanardelli      3             1895
# 4353        via Rione Sirignano      1             1904
# 4354                  via Serra      3             1895
# 4357         villa von Weinhart      1             1895
# 4358                        NaN    692             1894
#
#                  First name Last name Last name of the artist  \
# 0                    Alfred STIEGLITZ               STIEGLITZ
# 2              Mme Gertrude KÄSEBIER                KÄSEBIER
# 8                     George DAVISON                 DAVISON
# 18                    Pierre DUBREUIL                DUBREUIL
# 23                    George DAVISON                 DAVISON
# ...                               ...                     ...
# 4350             Comte Louis PRIMOLI                 PRIMOLI
# 4353  le Chevalier Gaetano TARANTINI               TARANTINI
# 4354                      D. FERRARI                 FERRARI
# 4357              Mme Florence FRITH                   FRITH
# 4358                 Bernard ALFIERI                 ALFIERI
#
#      First name of the artist Sex of the artist (F/M/FM/empty)  \
# 0                      Alfred                             male
# 2                Mme Gertrude                           female
# 8                      George                             male
# 18                     Pierre                             male
# 23                     George                             male
# ...                       ...                              ...
# 4350              Comte Louis                             male
# 4353     le Chevalier Gaetano                             male
# 4354                       D.                          unknown
# 4357             Mme Florence                           female
# 4358                  Bernard                             male
#
#      Membership in movement, if applicable  \
# 0                              Linked Ring
# 2                              Linked Ring
# 8                              Linked Ring
# 18                     Photo-Club de Paris
# 23                             Linked Ring
# ...                                    ...
# 4350                                   NaN
# 4353                                   NaN
# 4354                                   NaN
# 4357                                   NaN
# 4358                                   NaN
#
#                                   Biographical elements  \
# 0             L. R. 3 W, 29me rue, New-York (U. S. A.).
# 2             L. R. 3 W. 29me rue, New-York (U. S. A.).
# 8           L. R. Arnisson Road, Clovelly (Angleterre).
# 18      P. C. P. Avenue Saint-Maur, La Madeleine (No...
# 23         L. R. Beechcroff, East Molesey (Angleterre).
# ...                                                 ...
# 4350    1, Via torre di Riona, palais Primoli, Rome ...
# 4353               7, Rione Sirignano, Naples (Italie).
# 4354                      via Serra, 9, Gênes (Italie).
# 4357                 villa von Weinhart, Méran (Tyrol).
# 4358                    Northwood Cricklewood, Londres.
#
#      Detailed address of the artist, as it appears in the catalogue  ...  \
# 0                   3 W, 29me rue, New-York (U. S. A.).              ...
# 2                   3 W. 29me rue, New-York (U. S. A.).              ...
# 8                 Arnisson Road, Clovelly (Angleterre).              ...
# 18              Avenue Saint-Maur, La Madeleine (Nord).              ...
# 23               Beechcroff, East Molesey (Angleterre).              ...
# ...                                                 ...              ...
# 4350    1, Via torre di Riona, palais Primoli, Rome ...              ...
# 4353               7, Rione Sirignano, Naples (Italie).              ...
# 4354                      via Serra, 9, Gênes (Italie).              ...
# 4357                 villa von Weinhart, Méran (Tyrol).              ...
# 4358                    Northwood Cricklewood, Londres.              ...
#
#       City long Street number of the artist's address  \
# 0    -74.000000
# 2    -74.000000
# 8     -4.400000
# 18     3.070278
# 23    -0.349160
# ...         ...                                   ...
# 4350  12.482778                                     1
# 4353  14.250000                                     7
# 4354   8.933983                                     9
# 4357  11.159419
# 4358  -0.127500
#
#      Street coordinate location  Street lat  Street long Number  \
# 0                           NaN         NaN          NaN    465
# 2                           NaN         NaN          NaN    290
# 8                           NaN         NaN          NaN    212
# 18                          NaN         NaN          NaN    184
# 23                          NaN         NaN          NaN    160
# ...                         ...         ...          ...    ...
# 4350                        NaN         NaN          NaN    490
# 4353                        NaN         NaN          NaN    683
# 4354                        NaN         NaN          NaN    247
# 4357                        NaN         NaN          NaN    259
# 4358                        NaN         NaN          NaN      6
#
#                    Title of artwork   Subtitle    Dimension_bis  \
# 0                        Printemps.        NaN              NaN
# 2                 Homme au Chapeau.        Pl.              NaN
# 8           Rivière dans le Sussex.        NaN              NaN
# 18    Frise pour chambre d'Enfants.     Ch. V.              NaN
# 23                  Effet du Matin.        NaN              NaN
# ...                             ...        ...              ...
# 4350        Invocation au Couvent.   D. G. cl.  Épreuve directe
# 4353                          Paix.     A. Pl.   Agrandissement
# 4354             Scène de Famille.      D. Pl.  Épreuve directe
# 4357           « Jopsy » Portrait.      D. Pl.  Épreuve directe
# 4358              Sur les Falaises.        NaN              NaN
#
#                                         Medium_bis
# 0                                              NaN
# 2                                Papier au platine
# 8                                              NaN
# 18                  Papier charbon velours Artigue
# 23                                             NaN
# ...                                            ...
# 4350  Papier au gelatino-chlorure (dit aristotype)
# 4353                             Papier au platine
# 4354                             Papier au platine
# 4357                             Papier au platine
# 4358                                           NaN
#
# [919 rows x 24 columns]

# %%
#Import de la librairie geopandas

import geopandas

# %%
#Création des colones 'Latitude' et 'Longitude' à partir des colonnes 'Street lat' et 'Street long'

df_street[['Latitude', 'Longitude']]= df_street[['Street lat', 'Street long']]
df_street.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 919 entries, 0 to 4358
# Data columns (total 26 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Street name of the address                                      918 non-null    object
#  1   Count                                                           919 non-null    int64
#  2   Exhibition_Date                                                 919 non-null    int64
#  3   First name Last name                                            919 non-null    object
#  4   Last name of the artist                                         919 non-null    object
#  5   First name of the artist                                        864 non-null    object
#  6   Sex of the artist (F/M/FM/empty)                                919 non-null    object
#  7   Membership in movement, if applicable                           300 non-null    object
#  8   Biographical elements                                           919 non-null    object
#  9   Detailed address of the artist, as it appears in the catalogue  919 non-null    object
#  10  Country of the artist                                           919 non-null    object
#  11  City of the artist                                              919 non-null    object
#  12  City coordinate location                                        919 non-null    object
#  13  City lat                                                        919 non-null    float64
#  14  City long                                                       919 non-null    float64
#  15  Street number of the artist's address                           896 non-null    object
#  16  Street coordinate location                                      446 non-null    object
#  17  Street lat                                                      446 non-null    float64
#  18  Street long                                                     446 non-null    float64
#  19  Number                                                          919 non-null    object
#  20  Title of artwork                                                919 non-null    object
#  21  Subtitle                                                        638 non-null    object
#  22  Dimension_bis                                                   523 non-null    object
#  23  Medium_bis                                                      577 non-null    object
#  24  Latitude                                                        446 non-null    float64
#  25  Longitude                                                       446 non-null    float64
# dtypes: float64(6), int64(2), object(18)
# memory usage: 193.9+ KB

# %%
#Indiquer que notre tableur df_cities est un tableur géoréférencé 

gdf_street = geopandas.GeoDataFrame(df_street, geometry=geopandas.points_from_xy(df_street.Longitude, df_street.Latitude))

# %%
# Définition du fond de carte

#Choix des coordonnées centrales
#loc = [27.783889, -97.510556]#centrement continent américain 
loc = [52.50, -13.35]#centrement Atlantique
title_html = '''
             <h3 align="center" style="font-size:16px"><b>Distribution of exhibitors' addresses according to the number of works exhibited
            </b></h3><h5 align="center">Frédérine Pradier - CC BY</h5> 
             '''.format(loc) +'\n'

animated_map = folium.Map(location=loc, tiles='Stamen toner', zoom_start=2)

animated_map.get_root().html.add_child(folium.Element(title_html))

animated_map #(pour l'afficher)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3fb35d58f46e4713a9fe7e23f4123b82%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A16px%22%3E%3Cb%3EDistribution%20of%20exhibitors%27%20addresses%20according%20to%20the%20number%20of%20works%20exhibited%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/b%3E%3C/h3%3E%3Ch5%20align%3D%22center%22%3EFr%C3%A9d%C3%A9rine%20Pradier%20-%20CC%20BY%3C/h5%3E%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3fb35d58f46e4713a9fe7e23f4123b82%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20 ...

# %%
gdf_street = gdf_street[gdf_street["Street name of the address"].notna()]

# %%
def create_map_markers(gdf_street, map_name):
    
    folium.CircleMarker(
        location=[gdf_street['Latitude'], gdf_street['Longitude']], 
        radius=0.4*gdf_street['Count'],
        color="red",
        fill=True,
        popup=folium.Popup(f"{gdf_street['Street name of the address'].title()} <br> {str(gdf_street['Count']).title()}" +" items represented", max_width=200),
        tooltip=f"{gdf_street['Street name of the address'].title()}<br> {str(gdf_street['Count']).title()}" +" items represented",
        data=gdf_street,
        columns=['Street name of the address', "Count"],
        legend_name="Number of items retrieved"
        
                 ).add_to(map_name)

# %%
gdf_street=gdf_street.dropna(subset=['Latitude', 'Longitude'])
gdf_street.apply(create_map_markers, map_name=animated_map, axis="columns")
animated_map.save('street.html') #pour enregistrer la carte
animated_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3fb35d58f46e4713a9fe7e23f4123b82%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A16px%22%3E%3Cb%3EDistribution%20of%20exhibitors%27%20addresses%20according%20to%20the%20number%20of%20works%20exhibited%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/b%3E%3C/h3%3E%3Ch5%20align%3D%22center%22%3EFr%C3%A9d%C3%A9rine%20Pradier%20-%20CC%20BY%3C/h5%3E%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3fb35d58f46e4713a9fe7e23f4123b82%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20 ...
