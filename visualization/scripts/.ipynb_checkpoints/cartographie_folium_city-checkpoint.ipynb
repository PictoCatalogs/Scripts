# %% [markdown]
# # Cartographie et diagramme des items exposés selon la ville des exposants

# %% [markdown]
# ## Cartographie

# %%
#Localiser le répertoire de travail 

import os
os.getcwd()
# Out:
# '/Users/frederinepradier/Documents/Université/UniGe/_Projet de recherche/analyses/scripts'

# %%
#Chargement des librairies

import pandas as pd

import matplotlib.pyplot as plt  
from collections import Counter
import matplotlib.ticker as ticker

# !pip install folium
import folium
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.9/bin/python3.9 -m pip install --upgrade pip' command.

# %%
#Désignation du fichier de travail (tableur csv)

path = '../data/PCP_complete.tsv'

# %%
#Création d'un tableur (dataframe)

df = pd.read_csv(path, sep='\t', index_col=[0])

# %%
#Aperçu des données 

df.head(3)
# Out:
#               Exhibition_Date First name Last name Last name of the artist  \
# File
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
# PCP_1894.tsv             1894            ALEXANDRE               ALEXANDRE
#
#              First name of the artist Sex of the artist (F/M/FM/empty)  \
# File
# PCP_1894.tsv                      NaN                             male
# PCP_1894.tsv                      NaN                             male
# PCP_1894.tsv                      NaN                             male
#
#              Membership in movement, if applicable  \
# File
# PCP_1894.tsv                                   NaN
# PCP_1894.tsv                                   NaN
# PCP_1894.tsv                                   NaN
#
#                      Biographical elements  \
# File
# PCP_1894.tsv    268, rue Haute, Bruxelles.
# PCP_1894.tsv    268, rue Haute, Bruxelles.
# ...

# %%
#Aperçu des données 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5050 entries, PCP_1894.tsv to PCP_1895.tsv
# Data columns (total 23 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Exhibition_Date                                                 5050 non-null   int64
#  1   First name Last name                                            5050 non-null   object
#  2   Last name of the artist                                         5050 non-null   object
#  3   First name of the artist                                        4825 non-null   object
#  4   Sex of the artist (F/M/FM/empty)                                5050 non-null   object
#  5   Membership in movement, if applicable                           2411 non-null   object
#  6   Biographical elements                                           5049 non-null   object
# ...

# %%
#Créer un nouveau tableur avec le compte du nombre d'items pour chaque ville des exposants

cities_nb = Counter(df['City of the artist'].sort_values(ascending=True).tolist()).most_common()
df_cities = pd.DataFrame(cities_nb, columns=['City of the artist', 'Count'])
df_cities
# Out:
#     City of the artist  Count
# 0                Paris   1751
# 1               London    362
# 2               Vienna    230
# 3     City of Brussels    186
# 4        New York City    104
# ..                 ...    ...
# 322             Veurne      1
# 323          Wimbledon      1
# 324            Windsor      1
# 325           Worthing      1
# 326              Ypres      1
#
# [327 rows x 2 columns]

# %%
#Récupération des coordonnées géographiques

#Création d'un tableur avec les villes pour index et ajout de certaines données du tableur cleandata

df_cities = df_cities.set_index("City of the artist").join(df.set_index("City of the artist"), how="right").reset_index() 
df_cities.head()
# Out:
#   City of the artist  Count  Exhibition_Date   First name Last name  \
# 0          Abbeville      1             1906           PICARD-JOSSE
# 1    Aix-en-Provence     17             1906  Mlle Céline LAGUARDE
# 2    Aix-en-Provence     17             1906  Mlle Céline LAGUARDE
# 3    Aix-en-Provence     17             1906  Mlle Céline LAGUARDE
# 4    Aix-en-Provence     17             1906  Mlle Céline LAGUARDE
#
#   Last name of the artist First name of the artist  \
# 0            PICARD-JOSSE                      NaN
# 1               LAGUARDE               Mlle Céline
# 2               LAGUARDE               Mlle Céline
# 3               LAGUARDE               Mlle Céline
# 4               LAGUARDE               Mlle Céline
#
#   Sex of the artist (F/M/FM/empty) Membership in movement, if applicable  \
# 0                          unknown                                   NaN
# 1                           female                   Photo-Club de Paris
# ...

# %%
#Suppression des doublons 

df_cities.drop_duplicates(subset=['City of the artist'], keep = 'first', inplace=True)
df_cities
# Out:
#      City of the artist  Count  Exhibition_Date          First name Last name  \
# 0             Abbeville      1             1906                  PICARD-JOSSE
# 1       Aix-en-Provence     17             1906         Mlle Céline LAGUARDE
# 18               Albany     11             1898           Géo COMSTOCK BAKER
# 29                 Albi      1             1896                   J. GRIMAUD
# 30             Alderley      1             1894                HORGLSON BRIAN
# ...                 ...    ...              ...                           ...
# 5014              Ypres      1             1902                René ROUSSEAU
# 5015         Zanesville      3             1904       Mme George A. STANBERG
# 5018             Zürich     11             1906               Albert KAPTEYN
# 5029            Épernay      4             1906          Mlle de LASSUCHETTE
# 5033                NaN     17             1894  Mlle Julia Margaret CAMERON
#
# ...

# %%
#Import de la librairie geopandas

import geopandas

# %%
#Création des colones 'Latitude' et 'Longitude' à partir des colonnes 'City lat' et 'City long'

df_cities[['Latitude', 'Longitude']]= df_cities[['City lat', 'City long']]
df_cities.info(4)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 327 entries, 0 to 5033
# Data columns (total 26 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   City of the artist                                              326 non-null    object
#  1   Count                                                           327 non-null    int64
#  2   Exhibition_Date                                                 327 non-null    int64
#  3   First name Last name                                            327 non-null    object
#  4   Last name of the artist                                         327 non-null    object
#  5   First name of the artist                                        308 non-null    object
#  6   Sex of the artist (F/M/FM/empty)                                327 non-null    object
# ...

# %%
#Indiquer à Python que notre tableur df_cities est un tableur géoréférencé 

gdf_cities = geopandas.GeoDataFrame(df_cities, geometry=geopandas.points_from_xy(df_cities.Longitude, df_cities.Latitude))

# %%
#Visualisation selon la taille des points 

gdf_cities.plot(markersize=gdf_cities['Count'])
# Out:
# <AxesSubplot:>

# %%
# NOTRE FOND DE CARTE

#loc = [27.783889, -97.510556]#centrement continent américain 
loc = [52.50, -13.35]#centrement Atlantique
title_html = '''
             <h3 align="center" style="font-size:16px"><b>Repartition of the Visual Contagion Projects Sources 
            </b></h3><h5>Université de Genève</h5> 
             '''.format(loc) +'\n'

animated_map = folium.Map(location=loc, tiles='Stamen toner', zoom_start=2)

animated_map.get_root().html.add_child(folium.Element(title_html))

#indique les coordonnées centrales de la carte animée
#si vous voulez voir ce que donnera votre fond de carte : 
animated_map #(pour l'afficher)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
gdf_cities = gdf_cities[gdf_cities["City of the artist"].notna()]

# %%
def create_map_markers(gdf_cities, map_name):
    
    folium.CircleMarker(
        location=[gdf_cities['Latitude'], gdf_cities['Longitude']], 
        radius=0.05*gdf_cities['Count'], 
        fill=True,
        popup=folium.Popup(f"{gdf_cities['City of the artist'].title()} <br> {str(gdf_cities['Count']).title()}" +" items represented", max_width=200),
        tooltip=f"{gdf_cities['City of the artist'].title()}<br> {str(gdf_cities['Count']).title()}" +" items represented",
        data=gdf_cities,
        columns=["City of the artist", "Count"],
        legend_name="Number of items retrieved"
        
                 ).add_to(map_name)

# %%
gdf_cities=gdf_cities.dropna(subset=['Latitude', 'Longitude'])
gdf_cities.apply(create_map_markers, map_name=animated_map, axis="columns")
#titre de la carte, daté; '\n' permet d'aller à la ligne
animated_map.save('cities_map.html')
animated_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
